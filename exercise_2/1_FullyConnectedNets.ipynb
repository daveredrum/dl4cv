# (Epoch 4 / 10) train acc: 0.390000; val_acc: 0.358000
# (Iteration 161 / 400) loss: 1.628676
# (Iteration 166 / 400) loss: 1.577851
# (Iteration 171 / 400) loss: 1.601501
# (Iteration 176 / 400) loss: 1.751823
# (Iteration 181 / 400) loss: 1.771369
# (Iteration 186 / 400) loss: 1.538867
# (Iteration 191 / 400) loss: 1.621796
# (Iteration 196 / 400) loss: 1.558242
# (Epoch 5 / 10) train acc: 0.415000; val_acc: 0.352000
# (Iteration 201 / 400) loss: 1.566159
# (Iteration 206 / 400) loss: 1.484812
# (Iteration 211 / 400) loss: 1.582663
# (Iteration 216 / 400) loss: 1.485555
# (Iteration 221 / 400) loss: 1.700490
# (Iteration 226 / 400) loss: 1.456923
# (Iteration 231 / 400) loss: 1.567942
# (Iteration 236 / 400) loss: 1.518716
# (Epoch 6 / 10) train acc: 0.432000; val_acc: 0.362000
# (Iteration 241 / 400) loss: 1.461678
# (Iteration 246 / 400) loss: 1.460557
# (Iteration 251 / 400) loss: 1.603420
# (Iteration 256 / 400) loss: 1.620280
# (Iteration 261 / 400) loss: 1.589115
# (Iteration 266 / 400) loss: 1.447169
# (Iteration 271 / 400) loss: 1.622667
# (Iteration 276 / 400) loss: 1.579695
# (Epoch 7 / 10) train acc: 0.475000; val_acc: 0.370000
# (Iteration 281 / 400) loss: 1.350718
# (Iteration 286 / 400) loss: 1.529932
# (Iteration 291 / 400) loss: 1.544852
# (Iteration 296 / 400) loss: 1.615667
# (Iteration 301 / 400) loss: 1.624573
# (Iteration 306 / 400) loss: 1.334955
# (Iteration 311 / 400) loss: 1.364091
# (Iteration 316 / 400) loss: 1.381394
# (Epoch 8 / 10) train acc: 0.456000; val_acc: 0.383000
# (Iteration 321 / 400) loss: 1.345285
# (Iteration 326 / 400) loss: 1.537477
# (Iteration 331 / 400) loss: 1.381938
# (Iteration 336 / 400) loss: 1.423114
# (Iteration 341 / 400) loss: 1.467443
# (Iteration 346 / 400) loss: 1.486162
# (Iteration 351 / 400) loss: 1.523202
# (Iteration 356 / 400) loss: 1.686192
# (Epoch 9 / 10) train acc: 0.481000; val_acc: 0.380000
# (Iteration 361 / 400) loss: 1.438541
# (Iteration 366 / 400) loss: 1.456355
# (Iteration 371 / 400) loss: 1.322351
# (Iteration 376 / 400) loss: 1.407680
# (Iteration 381 / 400) loss: 1.422273
# (Iteration 386 / 400) loss: 1.379616
# (Iteration 391 / 400) loss: 1.378120
# (Iteration 396 / 400) loss: 1.349701
# (Epoch 10 / 10) train acc: 0.547000; val_acc: 0.388000

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 48% accuracy on the validation set using a fully-connected net.
#
# You might find it useful to complete the `2_BatchNormalization.ipynb` notebook before completing this part, since this technique can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# batch normalization and dropout useful. Store your best model in the         #
# best_model variable.                                                         #
# Note that dropout is not required to pass beyond the linear scoring regime   #
################################################################################
update_rules = ['adam', 'sgd_momentum']
# learning_rates = [1e-4, 2e-4, 3e-4, 4e-4, 5e-4]
# reg_strenths = [1e-4, 1e-3, 1e-2, 1e-1]
learning_rates = [1e-4]
reg_strenths = [1e-3, 1e-2]
hidden_dims = [100, 200, 200, 100]
dropouts = [0]
weight_scale = 3e-3
best_acc = 0
best_model = None
for update_rule in update_rules:
    for learning_rate in learning_rates:
        for reg_strenth in reg_strenths:
            for dropout in dropouts:
                print('running with: {}'.format(update_rule))
                print('learning_rate: {}'.format(learning_rate))
                print('regularization_strenth: {}'.format(reg_strenth))
                print('dropout: {}\n'.format(dropout))
                model = FullyConnectedNet(hidden_dims, 
                                          weight_scale=weight_scale, 
                                          use_batchnorm=True, 
#                                           reg=reg_strenth,
                                          dropout=dropout)
                solver = Solver(model, data,
                                num_epochs=20, batch_size=500,
                                update_rule=update_rule,
                                optim_config={
                                    'learning_rate': learning_rate
                                },
                                verbose=True,
                                print_every=20)
                solver.train()
                acc = solver.check_accuracy(data['X_val'], data['y_val'])
                if acc >= best_acc:
                    best_acc = acc
                    best_model = model
                del(model)
                del(solver)
                print()
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# running
# (Iteration 981 / 1920) loss: 1.239643
# (Iteration 1001 / 1920) loss: 1.249293
# (Iteration 1021 / 1920) loss: 1.111423
# (Iteration 1041 / 1920) loss: 1.230716
# (Epoch 11 / 20) train acc: 0.601000; val_acc: 0.474000
# (Iteration 1061 / 1920) loss: 1.127880
# (Iteration 1081 / 1920) loss: 1.155866
# (Iteration 1101 / 1920) loss: 1.159750
# (Iteration 1121 / 1920) loss: 1.173964
# (Iteration 1141 / 1920) loss: 1.030060
# (Epoch 12 / 20) train acc: 0.593000; val_acc: 0.483000
# (Iteration 1161 / 1920) loss: 1.113218
# (Iteration 1181 / 1920) loss: 1.023904
# (Iteration 1201 / 1920) loss: 1.115428
# (Iteration 1221 / 1920) loss: 1.126303
# (Iteration 1241 / 1920) loss: 1.044923
# (Epoch 13 / 20) train acc: 0.658000; val_acc: 0.482000
# (Iteration 1261 / 1920) loss: 1.046313
# (Iteration 1281 / 1920) loss: 1.087577
# (Iteration 1301 / 1920) loss: 1.093875
# (Iteration 1321 / 1920) loss: 1.058448
# (Iteration 1341 / 1920) loss: 1.036138
# (Epoch 14 / 20) train acc: 0.639000; val_acc: 0.477000
# (Iteration 1361 / 1920) loss: 1.025360
# (Iteration 1381 / 1920) loss: 1.043607
# (Iteration 1401 / 1920) loss: 0.940048
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-34fb8c4d3d81> in <module>()
#      38                                 verbose=True,
#      39                                 print_every=20)
# ---> 40                 solver.train()
#      41                 acc = solver.check_accuracy(data['X_val'], data['y_val'])
#      42                 if acc >= best_acc:
#
# /home/dave/Projects/dl4cv/exercise_2/dl4cv/solver.py in train(self)
#     221
#     222         for t in range(num_iterations):
# --> 223             self._step()
#     224
#     225             # Maybe print training loss
#
# /home/dave/Projects/dl4cv/exercise_2/dl4cv/solver.py in _step(self)
#     161
#     162         # Compute loss and gradient
# --> 163         loss, grads = self.model.loss(X_batch, y_batch)
#     164         self.loss_history.append(loss)
#     165
#
# /home/dave/Projects/dl4cv/exercise_2/dl4cv/classifiers/fc_net.py in loss(self, X, y)
#     295         for i in reversed(range(1, self.num_layers)):
#     296             if self.use_batchnorm and not self.use_dropout:
# --> 297                 dx[i], grads['W%d' % i], grads['b%d' % i], grads['gamma%d' % i], grads['beta%d' % i] = affine_relu_norm_backward(dx[i + 1], cache_layer[i])
#     298                 grads['W%d' % i] += self.reg * self.params['W%d' % i]
#     299             elif self.use_batchnorm and self.use_dropout:
#
# /home/dave/Projects/dl4cv/exercise_2/dl4cv/layer_utils.py in affine_relu_norm_backward(dout, cache)
#      38     ar_cache, norm_cache = cache
#      39     dnorm, dgamma, dbeta = batchnorm_backward(dout, norm_cache)
# ---> 40     dx, dw, db = affine_relu_backward(dnorm, ar_cache)
#      41     return dx, dw, db, dgamma, dbeta
#      42
#
# /home/dave/Projects/dl4cv/exercise_2/dl4cv/layer_utils.py in affine_relu_backward(dout, cache)
#      26     fc_cache, relu_cache = cache
#      27     da = relu_backward(dout, relu_cache)
# ---> 28     dx, dw, db = affine_backward(da, fc_cache)
#      29     return dx, dw, db
#      30
#
# /home/dave/Projects/dl4cv/exercise_2/dl4cv/layers.py in affine_backward(dout, cache)
#      59     x_flattened = x.reshape((x.shape[0], -1))
#      60     dx = np.dot(dout, w.T).reshape(x.shape)
# ---> 61     dw = np.dot(x_flattened.T, dout)
#      62     db = np.sum(dout, axis=0)
#      63     #############################################################################
#
# KeyboardInterrupt:

# %% [markdown]
# # Test you model
# Run your best model on the validation and test sets. You should achieve above 48% accuracy on the validation set.

# %%
X_test = data['X_test']
X_val = data['X_val']
y_val = data['y_val']
y_test = data['y_test']

y_test_pred = np.argmax(best_model.loss(X_test), axis=1)
y_val_pred = np.argmax(best_model.loss(X_val), axis=1)
print('Validation set accuracy: ', (y_val_pred == y_val).mean())
print('Test set accuracy: ', (y_test_pred == y_test).mean())
# Out:
# Validation set accuracy:  0.544
# Test set accuracy:  0.553

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.

# %%
from dl4cv.model_savers import save_fully_connected_net
save_fully_connected_net(model)

# %% [markdown]
# ## Scoring function
# We will score the model you have just saved based on the classification accuracy on our test dataset. The scoring function should represent the difficulty of obtaining a good test accuracy and should therefore give 0 points for worse results than random guessing, should be linear in a first regime and exponential beyond that. The onset of exponential growth depends on the problem. In that region you get twice as many points for an additional 10% accuracy.
#
# For this problem we specifically use the following scoring function:
#
# $$f(x) = \left\{
# 	\begin{array}{ll}
# 		0  & \mbox{if } x \leq 0.1 \\
# 		100x & \mbox{if } 0.1 < x \leq 0.5 \\
#         \left(\frac{50}{\exp(0.5 \ln(2)/0.1)}\right) \exp(x \ln(2)/0.1) & \mbox{if } 0.5 < x \leq 1
# 	\end{array}
# \right.$$
#
# The function can be plotted in the following cell.

# %%
from dl4cv.data_utils import scoring_function

x = np.linspace(0, 1, num=1000)
plt.plot(x, scoring_function(x, lin_exp_boundary=0.5, doubling_rate=0.1))
plt.title('Scoring Function')
plt.xlabel('Test Accuracy')
plt.ylabel('Score')
plt.show()
